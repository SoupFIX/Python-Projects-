# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cleaned_titanic_data.csv')
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked', 'Has_Cabin', 'Title', 'Family_Size', 'IsAlone', 'AgeGroup',
#        'Farebins'],
#       dtype='object')

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Has_Cabin  \
# 0         0       3    0  22.0      1      0   7.2500        S          0
# 1         1       1    1  38.0      1      0  71.2833        C          1
# 2         1       3    1  26.0      0      0   7.9250        S          0
# 3         1       1    1  35.0      1      0  53.1000        S          1
# 4         0       3    0  35.0      0      0   8.0500        S          0
#
#   Title  Family_Size  IsAlone     AgeGroup   Farebins
# 0    Mr            2        0  Young Adult        Low
# 1   Mrs            2        0        Adult  Very High
# 2  Miss            1        1  Young Adult     medium
# 3   Mrs            2        0  Young Adult  Very High
# 4    Mr            1        1  Young Adult     medium

# %%
df = pd.get_dummies(df,columns = ['Farebins','AgeGroup','Title'],dtype = int)
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Has_Cabin  \
# 0         0       3    0  22.0      1      0   7.2500        S          0
# 1         1       1    1  38.0      1      0  71.2833        C          1
# 2         1       3    1  26.0      0      0   7.9250        S          0
# 3         1       1    1  35.0      1      0  53.1000        S          1
# 4         0       3    0  35.0      0      0   8.0500        S          0
#
#    Family_Size  ...  AgeGroup_Adult  AgeGroup_Senior  AgeGroup_Teen  \
# 0            2  ...               0                0              0
# 1            2  ...               1                0              0
# 2            1  ...               0                0              0
# 3            2  ...               0                0              0
# 4            1  ...               0                0              0
#
#    AgeGroup_Young Adult  AgeGroup_child  Title_Master  Title_Miss  Title_Mr  \
# ...

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked', 'Has_Cabin', 'Family_Size', 'IsAlone', 'Farebins_High',
#        'Farebins_Low', 'Farebins_Very High', 'Farebins_medium',
#        'AgeGroup_Adult', 'AgeGroup_Senior', 'AgeGroup_Teen',
#        'AgeGroup_Young Adult', 'AgeGroup_child', 'Title_Master', 'Title_Miss',
#        'Title_Mr', 'Title_Mrs', 'Title_rare'],
#       dtype='object')

# %%
pd.set_option('display.max_rows',None);

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Has_Cabin  \
# 0         0       3    0  22.0      1      0   7.2500        S          0
# 1         1       1    1  38.0      1      0  71.2833        C          1
# 2         1       3    1  26.0      0      0   7.9250        S          0
# 3         1       1    1  35.0      1      0  53.1000        S          1
# 4         0       3    0  35.0      0      0   8.0500        S          0
#
#    Family_Size  ...  AgeGroup_Adult  AgeGroup_Senior  AgeGroup_Teen  \
# 0            2  ...               0                0              0
# 1            2  ...               1                0              0
# 2            1  ...               0                0              0
# 3            2  ...               0                0              0
# 4            1  ...               0                0              0
#
#    AgeGroup_Young Adult  AgeGroup_child  Title_Master  Title_Miss  Title_Mr  \
# ...

# %%
df.to_csv('clean_titanic_data.csv')
